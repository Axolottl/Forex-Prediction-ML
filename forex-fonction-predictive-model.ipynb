# %% [markdown]
# Regression : Accuracy: 0.828
# Decision Tree : Accuracy: 0.466
# Random forest : Accuracy: 0.495

# %%
import importlib
import forex_fonction
importlib.reload(forex_fonction)
from forex_fonction import forex
import yfinance as yf

# %%
forexObj = forex()
forexObj.set_pred_day(1)
dff = forexObj.get_features('EUR','USD','2010-01-01','2023-03-25')
forexObj.split('2022-03-01')

forexObj.train_model(classification=False)
dff_pred = forexObj.predict(coef=1)
forexObj.score()
forexObj.show_evolution(rolling=3, sorted=True)
# Out:
# [*********************100%***********************]  1 of 1 completed
# RMSE: 0.00407
# MAE: 0.00314
# R^2: 0.614
# Accuracy: 0.828

# %%
importlib.reload(forex_fonction)
from forex_fonction import forex

forexObj2 = forex()
prediction = forexObj2.simulate_forecasting('EUR','USD','2022-03-01','2023-03-25')
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#            prediction     truth
# Date
# 2022-03-01   0.004178  0.003486
# 2022-03-02  -0.005206 -0.008316
# 2022-03-03  -0.004149 -0.002041
# 2022-03-04  -0.005203  -0.00455
# 2022-03-07  -0.009792 -0.019231
# ...               ...       ...
# 2023-03-20   0.004155  0.006472
# 2023-03-21   0.001474  0.004029
# 2023-03-22   0.004941  0.005509
# 2023-03-23  -0.000394  0.009616
# 2023-03-24   0.004321 -0.003533
#
# [279 rows x 2 columns]

# %%
prediction
# Out:
#                value
# Date
# 2022-05-02  0.006387
# 2022-05-03 -0.000821
# 2022-05-04   0.00406
# 2022-05-05  0.000747
# 2022-05-06 -0.004815
# ...              ...
# 2023-03-20    0.0034
# 2023-03-21  0.001335
# 2023-03-22  0.004144
# 2023-03-23 -0.000418
# 2023-03-24  0.003385
#
# [235 rows x 1 columns]
